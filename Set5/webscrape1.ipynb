# %% [markdown]
# <b>Web scraping, small examples</b>

# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# pip install beatifulsoup4
# pip install requests
from bs4 import BeautifulSoup
import requests

# %%
# define the URL of the webpage and download the raw HTML
url = "https://en.wikipedia.org/wiki/Rovaniemi"
page = requests.get(url)

# %%
# create a "soup object" of the raw web-page
soup = BeautifulSoup(page.content, "html.parser")

# %%
# find the city name in the website
# Note: you have to use the developer tools
# of your web browser (often F12) and find the details
# what you are trying to scrape
# in this case => <h1> with the id of firstHeading + get text inside this element
cityname = soup.find("h1", id="firstHeading").text
cityname

# if using class => class_
# if using id => use id
# Out:
# 'Rovaniemi'

# %%
# getting multiple elements, <tr> with class "mergedtoprow"
# this is the small summary table on the right side of the page
elements = soup.find_all("tr", class_="mergedtoprow")

# %%
# loop through all that matched with <tr> and class="mergedtoprow"
for e in elements:
    print(e.text)
# Out:
# Rovaniemen kaupunkiRovaniemi stadCity of Rovaniemi
# Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju.
# .mw-parser-output .ib-settlement-cols{text-align:center;display:table;width:100%}.mw-parser-output .ib-settlement-cols-row{display:table-row}.mw-parser-output .ib-settlement-cols-cell{display:table-cell;vertical-align:middle}.mw-parser-output .ib-settlement-cols-cellt{display:table-cell;vertical-align:top}
#
# FlagCoat of arms
# Nickname(s): Arctic Capital; Hometown of Santa Claus
# Location of Rovaniemi in Finland
# CountryFinland
# Charter1960
# Government
# Area (2018-01-01)[1]
# Population (2023-12-31)[2]
# Population by native language[3]
# Population by age[4]
# Time zoneUTC+02:00 (EET)
# Websitewww.rovaniemi.fi

# %%
# get the municipality, a <span> with the title "English-language text"
municipality = soup.find("span", title="English-language text").text
municipality
# Out:
# 'City of Rovaniemi'

# %%
# div class ib-settlement-caption
caption_text = soup.find("div", class_="ib-settlement-caption").text
caption_text
# Out:
# 'Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju.'

# %% [markdown]
# <b>Let's try the timezone, which doesn't have a single identifier</b>
# <p>Instead we have to loop through a pile of elements to find the correct one</p>

# %%
# getting multiple elements, <tr> with class "mergedtoprow"
# this is the small summary table on the right side of the page
elements = soup.find_all("tr", class_="mergedtoprow")

# we have 14 elements (4.4.2024)
# len(elements)

# loop through the 14 elements
for e in elements:
    # print(e.text)

    # if we found an <th> which is not empty
    if e.find("th") != None:
        # if this <th> has the text => "Time Zone"
        if e.find('th').find(string=True) == "Time zone":
            info = e.findNext("td")
            print(info.text)
            break
# Out:
# UTC+02:00 (EET)

# %%
e
# Out:
# <tr class="mergedtoprow"><th class="infobox-label" scope="row"><a href="/wiki/Time_zone" title="Time zone">Time zone</a></th><td class="infobox-data"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">UTC+02:00</a> (<a href="/wiki/Eastern_European_Time" title="Eastern European Time">EET</a>)</td></tr>

# %%
elements
# Out:
# [<tr class="mergedtoprow ib-settlement-official"><td class="infobox-full-data" colspan="2"><span title="Finnish-language text"><i lang="fi">Rovaniemen kaupunki</i></span><br/><span title="Swedish-language text"><i lang="sv">Rovaniemi stad</i></span><br/><span title="English-language text"><span lang="en">City of Rovaniemi</span></span></td></tr>,
#  <tr class="mergedtoprow"><td class="infobox-full-data" colspan="2"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi_Montage.jpg" title="Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju."><img alt="Clockwise from top: the Rovaniemi Church, the Rovaniemi Airport, the Santa Claus Village, downtown Rovaniemi, a view of the city from Ounasvaara, the Arktikum Science Museum, and aurora borealis in Someroharju." class="mw-file-element" data-file-height="2832" data-file-width="1750" decoding="async" height="405" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Rovaniemi_Montage.jpg/250px-Rovaniemi_Montage.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Rovaniemi_Montage.jpg/375px-Rovaniemi_Montage.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Rovaniemi_Montage.jpg/500px-Rovaniemi_Montage.jpg 2x" width="250"/></a></span><div class="ib-settlement-caption">Clockwise from top: the <a href="/wiki/Rovaniemi_Church" title="Rovaniemi Church">Rovaniemi Church</a>, the <a href="/wiki/Rovaniemi_Airport" title="Rovaniemi Airport">Rovaniemi Airport</a>, the <a href="/wiki/Santa_Claus_Village" title="Santa Claus Village">Santa Claus Village</a>, downtown Rovaniemi, a view of the city from Ounasvaara, the <a href="/wiki/Arktikum_Science_Museum" title="Arktikum Science Museum">Arktikum Science Museum</a>, and <a class="mw-redirect" href="/wiki/Aurora_borealis" title="Aurora borealis">aurora borealis</a> in Someroharju.</div></td></tr>,
#  <tr class="mergedtoprow"><td class="infobox-full-data maptable" colspan="2"><style data-mw-deduplicate="TemplateStyles:r1028600610">.mw-parser-output .ib-settlement-cols{text-align:center;display:table;width:100%}.mw-parser-output .ib-settlement-cols-row{display:table-row}.mw-parser-output .ib-settlement-cols-cell{display:table-cell;vertical-align:middle}.mw-parser-output .ib-settlement-cols-cellt{display:table-cell;vertical-align:top}</style>
#  <div class="ib-settlement-cols">
#  <div class="ib-settlement-cols-row"><div class="ib-settlement-cols-cell"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi.lippu.svg" title="Flag of Rovaniemi"><img alt="Flag of Rovaniemi" class="mw-file-element" data-file-height="800" data-file-width="1200" decoding="async" height="70" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/105px-Rovaniemi.lippu.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/158px-Rovaniemi.lippu.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Rovaniemi.lippu.svg/210px-Rovaniemi.lippu.svg.png 2x" width="105"/></a></span><div class="ib-settlement-caption-link">Flag</div></div><div class="ib-settlement-cols-cell"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi.vaakuna.svg" title="Coat of arms of Rovaniemi"><img alt="Coat of arms of Rovaniemi" class="mw-file-element" data-file-height="568" data-file-width="500" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/70px-Rovaniemi.vaakuna.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/106px-Rovaniemi.vaakuna.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Rovaniemi.vaakuna.svg/141px-Rovaniemi.vaakuna.svg.png 2x" width="70"/></a></span><div class="ib-settlement-caption-link">Coat of arms</div></div></div></div></td></tr>,
#  <tr class="mergedtoprow"><td class="infobox-full-data" colspan="2">Nickname(s): <div class="ib-settlement-nickname nickname">Arctic Capital; Hometown of <a href="/wiki/Santa_Claus" title="Santa Claus">Santa Claus</a></div></td></tr>,
#  <tr class="mergedtoprow"><td class="infobox-full-data" colspan="2"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Rovaniemi_sijainti_Suomi.svg" title="Location of Rovaniemi in Finland"><img alt="Location of Rovaniemi in Finland" class="mw-file-element" data-file-height="2950" data-file-width="1750" decoding="async" height="421" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Rovaniemi_sijainti_Suomi.svg/250px-Rovaniemi_sijainti_Suomi.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Rovaniemi_sijainti_Suomi.svg/375px-Rovaniemi_sijainti_Suomi.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Rovaniemi_sijainti_Suomi.svg/500px-Rovaniemi_sijainti_Suomi.svg.png 2x" width="250"/></a></span><div class="ib-settlement-caption">Location of Rovaniemi in Finland</div></td></tr>,
#  <tr class="mergedtoprow"><th class="infobox-label" scope="row">Country</th><td class="infobox-data">Finland</td></tr>,
#  <tr class="mergedtoprow"><th class="infobox-label" scope="row"><a href="/wiki/Charter" title="Charter">Charter</a></th><td class="infobox-data">1960</td></tr>,
#  <tr class="mergedtoprow"><th class="infobox-header" colspan="2">Government<div class="ib-settlement-fn"></div></th></tr>,
#  <tr class="mergedtoprow"><th class="infobox-header" colspan="2">Area<div class="ib-settlement-fn"> (2018-01-01)<sup class="reference" id="cite_ref-total_area_1-0"><a href="#cite_note-total_area-1">[1]</a></sup></div></th></tr>,
#  <tr class="mergedtoprow"><th class="infobox-header" colspan="2">Population<div class="ib-settlement-fn"><span class="nowrap"> </span>(2023-12-31)<sup class="reference" id="cite_ref-population_count_2-0"><a href="#cite_note-population_count-2">[2]</a></sup></div></th></tr>,
#  <tr class="mergedtoprow"><th class="infobox-header" colspan="2"><a href="/wiki/Languages_of_Finland" title="Languages of Finland">Population by native language</a><div class="ib-settlement-fn"><sup class="reference" id="cite_ref-population_by_language_3-0"><a href="#cite_note-population_by_language-3">[3]</a></sup></div></th></tr>,
#  <tr class="mergedtoprow"><th class="infobox-header" colspan="2"><a class="mw-redirect" href="/wiki/Demographics" title="Demographics">Population by age</a><div class="ib-settlement-fn"><sup class="reference" id="cite_ref-demography_4-0"><a href="#cite_note-demography-4">[4]</a></sup></div></th></tr>,
#  <tr class="mergedtoprow"><th class="infobox-label" scope="row"><a href="/wiki/Time_zone" title="Time zone">Time zone</a></th><td class="infobox-data"><a href="/wiki/UTC%2B02:00" title="UTC+02:00">UTC+02:00</a> (<a href="/wiki/Eastern_European_Time" title="Eastern European Time">EET</a>)</td></tr>,
#  <tr class="mergedtoprow"><th class="infobox-label" scope="row">Website</th><td class="infobox-data"><a class="external text" href="https://international.rovaniemi.fi/en" rel="nofollow">www.rovaniemi.fi</a></td></tr>]

# %% [markdown]
# <b>Let's try scraping an HTML table instead</b>

# %%
# page with multiple tables
url = "https://en.wikipedia.org/wiki/List_of_best-selling_video_games"

# use pandas to read all HTML-tables from a website
tables = pd.read_html(url)

# %%
# in this case, we're interested in the 2nd table
# (the 1st one is the small menu on the top left)
actual_data = tables[1]

# %%
# and this is a DataFrame
actual_data
# Out:
#                                           Title      Sales  \
# 0                                     Minecraft  300000000
# 1                            Grand Theft Auto V  195000000
# 2                                   Tetris (EA)  100000000
# 3                                    Wii Sports   82900000
# 4                           PUBG: Battlegrounds   75000000
# 5                         Mario Kart 8 / Deluxe   69040000
# 6                         Red Dead Redemption 2   61000000
# 7                             Super Mario Bros.   58000000
# 8                                     Overwatch   50000000
# 9                              Human: Fall Flat   50000000
# 10                     The Witcher 3: Wild Hunt   50000000
# 11                      Tetris (Game Boy / NES)   48000000
# 12          Pokémon Red / Green / Blue / Yellow   47520000
# 13                Animal Crossing: New Horizons   44790000
# 14                                     Terraria   44500000
# 15                               Wii Fit / Plus   43800000
# 16                                      Pac-Man   42071635
# 17                               Mario Kart Wii   37380000
# 18                   Super Smash Bros. Ultimate   33670000
# 19      The Legend of Zelda: Breath of the Wild   33310000
# 20                            Wii Sports Resort   33140000
# 21                        New Super Mario Bros.   30800000
# 22                    New Super Mario Bros. Wii   30320000
# 23                 Call of Duty: Modern Warfare   30000000
# 24                                   Diablo III   30000000
# 25                               Stardew Valley   30000000
# 26              Pokémon Gold / Silver / Crystal   29490000
# 27                                    Duck Hunt   28300000
# 28                                     Wii Play   28020000
# 29                             The Walking Dead   28000000
# 30                                Borderlands 2   28000000
# 31                          Super Mario Odyssey   27650000
# 32                Grand Theft Auto: San Andreas   27500000
# 33                            Super Mario World   26662500
# 34               Call of Duty: Modern Warfare 3   26500000
# 35                                      FIFA 18   26400000
# 36                      Call of Duty: Black Ops   26200000
# 37                       Pokémon Sword / Shield   26170000
# 38   New Super Mario Bros. U / Luigi U / Deluxe   26090000
# 39  Pokémon Sun / Moon / Ultra Sun / Ultra Moon   25510000
# 40                          Grand Theft Auto IV   25000000
# 41                               Cyberpunk 2077   25000000
# 42                         Monster Hunter World   25000000
# 43           Pokémon Diamond / Pearl / Platinum   24730000
# 44                          Super Mario Bros. 3   24430000
# 45                     Pokémon Scarlet / Violet   24360000
# 46                            Horizon Zero Dawn   24300000
# 47                   Call of Duty: Black Ops II   24200000
# 48                              Hogwarts Legacy   24000000
# 49                           Kinect Adventures!   24000000
#
#                  Series                       Platform(s)  \
# 0             Minecraft                    Multi-platform
# 1      Grand Theft Auto                    Multi-platform
# 2                Tetris                    Multi-platform
# 3                   Wii                               Wii
# 4         PUBG Universe                    Multi-platform
# 5            Mario Kart                    Wii U / Switch
# 6              Red Dead                    Multi-platform
# 7           Super Mario                    Multi-platform
# 8             Overwatch                    Multi-platform
# 9      Human: Fall Flat                    Multi-platform
# 10          The Witcher                    Multi-platform
# 11               Tetris                    Game Boy / NES
# 12              Pokémon                    Multi-platform
# 13      Animal Crossing                   Nintendo Switch
# 14                  NaN                    Multi-platform
# 15                  Wii                               Wii
# 16              Pac-Man                    Multi-platform
# 17           Mario Kart                               Wii
# 18    Super Smash Bros.                   Nintendo Switch
# 19  The Legend of Zelda                    Wii U / Switch
# 20                  Wii                               Wii
# 21          Super Mario                       Nintendo DS
# 22          Super Mario                               Wii
# 23         Call of Duty                    Multi-platform
# 24               Diablo                    Multi-platform
# 25       Stardew Valley                    Multi-platform
# 26              Pokémon                    Game Boy Color
# 27                  NaN                               NES
# 28                  Wii                               Wii
# 29     The Walking Dead                    Multi-platform
# 30          Borderlands                    Multi-platform
# 31          Super Mario                   Nintendo Switch
# 32     Grand Theft Auto                    Multi-platform
# 33          Super Mario                    Multi-platform
# 34         Call of Duty                    Multi-platform
# 35                 FIFA                    Multi-platform
# 36         Call of Duty                    Multi-platform
# 37              Pokémon                   Nintendo Switch
# 38          Super Mario                    Wii U / Switch
# 39              Pokémon                      Nintendo 3DS
# 40     Grand Theft Auto                    Multi-platform
# 41            Cyberpunk                    Multi-platform
# 42       Monster Hunter  PlayStation 4, Xbox One, Windows
# 43              Pokémon                       Nintendo DS
# 44          Super Mario                    Multi-platform
# 45              Pokémon                   Nintendo Switch
# 46              Horizon           PlayStation 4 / Windows
# 47         Call of Duty                    Multi-platform
# 48      Wizarding World                    Multi-platform
# 49                  NaN                          Xbox 360
#
#     Initial release date                       Developer(s)[b]  \
# 0   November 18, 2011[c]                        Mojang Studios
# 1     September 17, 2013                        Rockstar North
# 2     September 12, 2006                             EA Mobile
# 3      November 19, 2006                          Nintendo EAD
# 4      December 20, 2017                          PUBG Studios
# 5           May 29, 2014  Nintendo EAD / Nintendo EPD (Deluxe)
# 6       October 26, 2018                        Rockstar Games
# 7     September 13, 1985                         Nintendo R&D4
# 8           May 24, 2016                Blizzard Entertainment
# 9          July 22, 2016                       No Brakes Games
# 10          May 19, 2015                        CD Projekt Red
# 11         June 14, 1989                         Nintendo R&D1
# 12     February 27, 1996                            Game Freak
# 13        March 20, 2020                          Nintendo EPD
# 14          May 16, 2011                              Re-Logic
# 15      December 1, 2007                          Nintendo EAD
# 16          May 22, 1980                                 Namco
# 17        April 10, 2008                          Nintendo EAD
# 18      December 7, 2018      Bandai Namco Studios / Sora Ltd.
# 19         March 3, 2017                          Nintendo EPD
# 20         June 25, 2009                          Nintendo EAD
# 21          May 15, 2006                          Nintendo EAD
# 22     November 11, 2009                          Nintendo EAD
# 23      October 25, 2019                         Infinity Ward
# 24          May 16, 2012                Blizzard Entertainment
# 25     February 26, 2016                          ConcernedApe
# 26     November 21, 1999                            Game Freak
# 27        April 21, 1984                         Nintendo R&D1
# 28      December 2, 2006                          Nintendo EAD
# 29        April 24, 2012                        Telltale Games
# 30    September 18, 2012                      Gearbox Software
# 31      October 27, 2017                          Nintendo EPD
# 32      October 26, 2004                        Rockstar North
# 33     November 21, 1990                          Nintendo EAD
# 34      November 8, 2011          Infinity Ward / Sledgehammer
# 35    September 29, 2017                          EA Vancouver
# 36      November 9, 2010                              Treyarch
# 37     November 15, 2019                            Game Freak
# 38     November 18, 2012                          Nintendo EAD
# 39     November 18, 2016                            Game Freak
# 40        April 29, 2008                        Rockstar North
# 41     December 10, 2020                        CD Projekt Red
# 42      January 18, 2018                                Capcom
# 43    September 28, 2006                            Game Freak
# 44      October 23, 1988                          Nintendo EAD
# 45     November 18, 2022                            Game Freak
# 46     February 28, 2017                       Guerrilla Games
# 47     November 12, 2012                              Treyarch
# 48     February 10, 2023                    Avalanche Software
# 49      November 4, 2010                   Good Science Studio
#
#                    Publisher(s)[b]  Ref.
# 0                   Mojang Studios   [4]
# 1                   Rockstar Games   [5]
# 2                  Electronic Arts   [6]
# 3                         Nintendo   [7]
# 4                          Krafton   [8]
# 5                         Nintendo   [d]
# 6                   Rockstar Games   [5]
# 7                         Nintendo   [e]
# 8           Blizzard Entertainment  [14]
# 9                    Curve Digital  [15]
# 10                      CD Projekt  [16]
# 11                        Nintendo   [f]
# 12                        Nintendo   [g]
# 13                        Nintendo  [10]
# 14            Re-Logic / 505 Games  [22]
# 15                        Nintendo   [h]
# 16                           Namco   [i]
# 17                        Nintendo   [7]
# 18                        Nintendo  [10]
# 19                        Nintendo   [j]
# 20                        Nintendo   [7]
# 21                        Nintendo  [34]
# 22                        Nintendo   [7]
# 23                      Activision  [35]
# 24          Blizzard Entertainment  [36]
# 25                    ConcernedApe  [37]
# 26                        Nintendo   [k]
# 27                        Nintendo  [39]
# 28                        Nintendo   [7]
# 29                  Telltale Games  [40]
# 30                        2K Games  [41]
# 31                        Nintendo  [10]
# 32                  Rockstar Games  [42]
# 33                        Nintendo   [l]
# 34                      Activision  [44]
# 35                       EA Sports   [m]
# 36                      Activision  [44]
# 37  Nintendo / The Pokémon Company  [10]
# 38                        Nintendo   [n]
# 39  Nintendo / The Pokémon Company   [o]
# 40                  Rockstar Games  [49]
# 41                      CD Projekt  [50]
# 42                          Capcom  [51]
# 43  Nintendo / The Pokémon Company   [p]
# 44                        Nintendo   [q]
# 45  Nintendo / The Pokémon Company  [10]
# 46  Sony Interactive Entertainment  [55]
# 47                      Activision  [44]
# 48              Warner Bros. Games  [56]
# 49               Xbox Game Studios  [57]

# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns

from bs4 import BeautifulSoup
import requests

# define the URL of the webpage and download the raw HTML
url = "https://en.wikipedia.org/wiki/Rovaniemi"
page = requests.get(url)

# create a "soup object" of the raw web-page
soup = BeautifulSoup(page.content, "html.parser")

coordinates_element = soup.find("span", class_="geo")
coordinates = coordinates_element.get_text()

nickname_element = soup.find("div", class_="ib-settlement-nickname nickname")
nickname = nickname_element.get_text() if nickname_element else "Nickname not found"

print(f"Coordinates of Rovaniemi: {coordinates}")
print(f"Nicknames of Rovaniemi: {nickname}")
# Out:
# Coordinates of Rovaniemi: 66.500; 25.733
# Nicknames of Rovaniemi: Arctic Capital; Hometown of Santa Claus
