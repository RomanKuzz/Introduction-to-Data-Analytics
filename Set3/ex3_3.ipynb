# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %load_ext numpy_html

# %%
# %%html
# <style>
# table {margin-top: 16pt;}
# td {font-family: Arial, Helvetica, sans-serif !important; font-weight: 600; white-space: normal !important;}
# tr:nth-child(even) {background: #b0d9eb !important; color: black}
# tr:nth-child(odd) {background: #8fb1bf !important; color: black}
# </style>
# Out:
# <style>
# table {margin-top: 16pt;}
# td {font-family: Arial, Helvetica, sans-serif !important; font-weight: 600; white-space: normal !important;}
# tr:nth-child(even) {background: #b0d9eb !important; color: black}
# tr:nth-child(odd) {background: #8fb1bf !important; color: black}
# </style>

# %%
# Read the Excel file into a DataFrame
food = pd.read_csv("C:/Users/Roman/Downloads/data_analytics2023materials/groceries.csv")

food['Fish'].fillna((food['Fish'].mean()), inplace=True)
food = food.drop('Tea', axis=1)
food = food.drop('Coffee', axis=1)
sns.pairplot(food)
plt.show()

# %%
matrix = food.corr(numeric_only=True)
matrix
# Out:
#                    Rice     Wheat    Barley      Corn   Peanuts     Sugar  \
# Rice           1.000000  0.764992  0.725854  0.820150  0.696030  0.704375
# Wheat          0.764992  1.000000  0.892162  0.890443  0.580613  0.640290
# Barley         0.725854  0.892162  1.000000  0.907648  0.609116  0.620424
# Corn           0.820150  0.890443  0.907648  1.000000  0.710431  0.755538
# Peanuts        0.696030  0.580613  0.609116  0.710431  1.000000  0.611945
# Sugar          0.704375  0.640290  0.620424  0.755538  0.611945  1.000000
# Coconut-oil    0.646414  0.618246  0.529652  0.680974  0.603114  0.691739
# Palm-oil       0.793909  0.822121  0.792855  0.837823  0.684083  0.761629
# Sunflower-oil -0.126897 -0.095667 -0.042231  0.015328 -0.293599 -0.194474
# Chicken        0.652289  0.646178  0.619077  0.678824  0.498765  0.564009
# Beef           0.616056  0.528809  0.432840  0.615079  0.628254  0.566042
# Pork           0.358760  0.399894  0.390245  0.481870  0.459738  0.377737
# Fish           0.473308  0.407069  0.296844  0.466458  0.393605  0.607986
#
#                Coconut-oil  Palm-oil  Sunflower-oil   Chicken      Beef  \
# Rice              0.646414  0.793909      -0.126897  0.652289  0.616056
# Wheat             0.618246  0.822121      -0.095667  0.646178  0.528809
# Barley            0.529652  0.792855      -0.042231  0.619077  0.432840
# Corn              0.680974  0.837823       0.015328  0.678824  0.615079
# Peanuts           0.603114  0.684083      -0.293599  0.498765  0.628254
# Sugar             0.691739  0.761629      -0.194474  0.564009  0.566042
# Coconut-oil       1.000000  0.835128       0.015663  0.659971  0.662576
# Palm-oil          0.835128  1.000000      -0.137750  0.645418  0.560498
# Sunflower-oil     0.015663 -0.137750       1.000000  0.092701 -0.564561
# Chicken           0.659971  0.645418       0.092701  1.000000  0.775428
# Beef              0.662576  0.560498      -0.564561  0.775428  1.000000
# Pork              0.289800  0.280837       0.031896  0.365066  0.458650
# Fish              0.608828  0.506403      -0.502210  0.389383  0.575151
#
#                    Pork      Fish
# Rice           0.358760  0.473308
# Wheat          0.399894  0.407069
# Barley         0.390245  0.296844
# Corn           0.481870  0.466458
# Peanuts        0.459738  0.393605
# Sugar          0.377737  0.607986
# Coconut-oil    0.289800  0.608828
# Palm-oil       0.280837  0.506403
# Sunflower-oil  0.031896 -0.502210
# Chicken        0.365066  0.389383
# Beef           0.458650  0.575151
# Pork           1.000000  0.387127
# Fish           0.387127  1.000000

# %%
sns.heatmap(matrix)
plt.show()
